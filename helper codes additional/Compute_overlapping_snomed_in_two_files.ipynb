# %%
#!/usr/bin/env python
# -*-coding:utf-8 -*-
'''
@File    :   condition_specific_functions_for_difficult_diseases.ipynb
@Time    :   2023/08/21 11:55:10
@Author  :   Asra Aslam 
@Version :   1.0
@Contact :   a.aslam2@leeds.ac.uk
@License :   (C)Copyright Asra Aslam DynAIRX
@Desc    :   This file is specifically designed for alcohol conditon, where we need to extract 
             snomed codes from other splitted categories and compare with categories in efi file
             and report the remaining ones
'''

import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
filepaths_source_database= "output/macular_degeneration/grouped_database_with_snomed_Visual Impairment and Blindness.csv" #"output/macular_degeneration/grouped_database_with_snomed_Cataract.csv" #"output/macular_degeneration/grouped_database_with_snomed_Macular Degeneration.csv"  
filepath_target_database="output/macular_degeneration/Remaining_Visual_Impairment2_not_in_Cataract.csv" #"output/macular_degeneration/Manual_Analysis_Visual_impairment_orig_before_reduce.csv" 
filepath_output_database_remaining_SNOMED="output/macular_degeneration/Remaining_Visual_Impairment3_not_in_Visual_Impairment_and_Blindness.csv"

# %%
df_database_target = pd.read_csv(filepath_target_database, dtype={'SnomedCTConceptId': str}) 
df_database_target
# Out:
#     SnomedCTConceptId                                Term   Disease  \
# 0            13973009                    Grand mal status  Seizures
# 1           161480008                       H/O: epilepsy  Seizures
# 2            16873003                Musicogenic epilepsy  Seizures
# 3           170702005                 Epilepsy monitoring  Seizures
# 4           170703000         Initial epilepsy assessment  Seizures
# ..                ...                                 ...       ...
# 119    88491000000102          Epilepsy limits activities  Seizures
# 120          91175000                   [D]Convulsion NOS  Seizures
# 121    93211000000101  Epilepsy does not limit activities  Seizures
# 122    93401000000104      Did not attend epilepsy clinic  Seizures
# 123          95208000             Photosensitive epilepsy  Seizures
#
#      Otherinstructions   origin
# 0                  NaN  ['efi']
# 1                  NaN  ['efi']
# 2                  NaN  ['efi']
# 3                  NaN  ['efi']
# 4                  NaN  ['efi']
# ..                 ...      ...
# 119                NaN  ['efi']
# 120                NaN  ['efi']
# 121                NaN  ['efi']
# 122                NaN  ['efi']
# 123                NaN  ['efi']
#
# [124 rows x 5 columns]

# %%
# rename SNOMEDCT_CONCEPTID, Deficit and Codedescription column in efi list same as LW list
# df_database_target.rename(columns={'SNOMEDCT_CONCEPTID':'SnomedCTConceptId'}, inplace=True)
# df_database_target.rename(columns={'Codedescription':'Term'}, inplace=True)
# df_database_target.rename(columns={'Deficit':'Disease'}, inplace=True)
df_database_target.columns
# Out:
# Index(['SnomedCTConceptId', 'Term', 'Disease', 'Otherinstructions', 'origin'], dtype='object')

# %%
df_database_target.dtypes
# Out:
# SnomedCTConceptId     object
# Term                  object
# Disease               object
# Otherinstructions    float64
# origin                object
# dtype: object

# %%
df_database_source = pd.read_csv(filepaths_source_database, dtype={'SnomedCTConceptId': str}) 
df_database_source
# Out:
#    SnomedCTConceptId                                               Term  \
# 0    108211000000104                         Epilepsy impairs education
# 1           13973009                                   Grand mal status
# 2          162658001                                  Epilepsy resolved
# 3          170702005                                Epilepsy monitoring
# 4          170702005                            Epilepsy monitoring NOS
# ..               ...                                                ...
# 95          84757009  [X]Other generalized epilepsy and epileptic sy...
# 96    88491000000102                         Epilepsy limits activities
# 97          89525009                                  Gelastic epilepsy
# 98    93401000000104               DNA - Did not attend epilepsy clinic
# 99          95208000                            Photosensitive epilepsy
#
#      Disease  Otherinstructions               origin
# 0   Epilepsy                NaN  ['Lauren_codelist']
# 1   Epilepsy                NaN  ['Lauren_codelist']
# 2   Epilepsy                NaN  ['Lauren_codelist']
# 3   Epilepsy                NaN  ['Lauren_codelist']
# 4   Epilepsy                NaN  ['Lauren_codelist']
# ..       ...                ...                  ...
# 95  Epilepsy                NaN  ['Lauren_codelist']
# 96  Epilepsy                NaN  ['Lauren_codelist']
# 97  Epilepsy                NaN  ['Lauren_codelist']
# 98  Epilepsy                NaN  ['Lauren_codelist']
# 99  Epilepsy                NaN  ['Lauren_codelist']
#
# [100 rows x 5 columns]

# %%
df_database_source.SnomedCTConceptId
# Out:
# 0     108211000000104
# 1            13973009
# 2           162658001
# 3           170702005
# 4           170702005
#            ...
# 95           84757009
# 96     88491000000102
# 97           89525009
# 98     93401000000104
# 99           95208000
# Name: SnomedCTConceptId, Length: 100, dtype: object

# %%
df_database_target.SnomedCTConceptId.isin(df_database_source.SnomedCTConceptId)
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 119     True
# 120    False
# 121    False
# 122     True
# 123     True
# Name: SnomedCTConceptId, Length: 124, dtype: bool

# %%
df_remaining_rows=df_database_target[~df_database_target.SnomedCTConceptId.isin(df_database_source.SnomedCTConceptId)]
df_remaining_rows
# Out:
#     SnomedCTConceptId                                Term   Disease  \
# 1           161480008                       H/O: epilepsy  Seizures
# 2            16873003                Musicogenic epilepsy  Seizures
# 4           170703000         Initial epilepsy assessment  Seizures
# 5           170704006       Follow-up epilepsy assessment  Seizures
# 6           170706008        Epilepsy associated problems  Seizures
# ..                ...                                 ...       ...
# 113          71831005    Symptomatic generalised epilepsy  Seizures
# 115           7689009                    Reading epilepsy  Seizures
# 117   840261000000103      Epilepsy management plan given  Seizures
# 120          91175000                   [D]Convulsion NOS  Seizures
# 121    93211000000101  Epilepsy does not limit activities  Seizures
#
#      Otherinstructions   origin
# 1                  NaN  ['efi']
# 2                  NaN  ['efi']
# 4                  NaN  ['efi']
# 5                  NaN  ['efi']
# 6                  NaN  ['efi']
# ..                 ...      ...
# 113                NaN  ['efi']
# 115                NaN  ['efi']
# 117                NaN  ['efi']
# 120                NaN  ['efi']
# 121                NaN  ['efi']
#
# [68 rows x 5 columns]

# %%
df_remaining_rows.to_csv(filepath_output_database_remaining_SNOMED, index=False)
