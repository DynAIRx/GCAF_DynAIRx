# %%
#!/usr/bin/env python
# -*-coding:utf-8 -*-
'''
@File    :   GCAF_Investigate_Related_Condition_Names.ipynb
@Time    :   2024/09/18 13:45:31
@Author  :   Asra Aslam 
@Version :   1.0
@Contact :   a.aslam2@leeds.ac.uk
@License :   (C)Copyright Asra Aslam DynAIRX
@Desc    :   None
'''
import pandas as pd
import re
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# Download necessary resources for part-of-speech tagging
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hssaas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hssaas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Read Excel file
df_comments = pd.read_excel('Clincians_Intervention_Split_Keep_Group.xlsx')
df_comments
# Out:
#                            eFI2 Deficits  \
# 0                      'Abdominal pain',
# 1                 'Activity limitation',
# 2                             'Alcohol',
# 3     'Anaemia & haematinic deficiency',
# 4                             'Anxiety',
# ..                                   ...
# 177                                  NaN
# 178                                  NaN
# 179                                  NaN
# 180                                  NaN
# 181                                  NaN
#
#                                           Comments_eFI  \
# 0    Liverpool list doesn't include chronic abdo pa...
# 1                                                  NaN
# 2    I would prefer to have distinct lists for alco...
# 3    I would prefer to separate these out and have ...
# 4         need to compare code lists for consistency.
# ..                                                 ...
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
#
#                         Liverpool Diseases  \
# 0                Abdominal Aortic Aneurysm
# 1                         Abdominal Hernia
# 2                                     Acne
# 3                         Acoustic Neuroma
# 4                        Actinic keratosis
# ..                                     ...
# 177                           Urolithiasis
# 178          Uterovaginal Genital Prolapse
# 179  Valve disorder non-rheumatic multiple
# 180        Visual Impairment and Blindness
# 181                               Vitiligo
#
#                                            Comments_LW
# 0        Keep this - not currently covered by eFI list
# 1        Keep this - not currently covered by eFI list
# 2        Keep this - not currently covered by eFI list
# 3    benign tumour - we could put all benign tumour...
# 4        Keep this - not currently covered by eFI list
# ..                                                 ...
# 177      Keep this - not currently covered by eFI list
# 178      Keep this - not currently covered by eFI list
# 179             can merge all the valve disorder lists
# 180  compare with eFI visual impairment list and me...
# 181      Keep this - not currently covered by eFI list
#
# [182 rows x 4 columns]

# %%
# Sample DataFrame (with collections of words in columns)
# data = {
#     'Liverpool Diseases': ['apple and banana', 'orange and grape', 'peach and plum', 'mango and papaya'],
#     'Comments_LW': ['red car and blue bike', 'fast train and slow plane', 'small boat', 'big ship'],
#     'Column3': ['dog and cat', 'bird and fish', 'elephant and giraffe', 'lion and tiger']
# }

# df = pd.DataFrame(data)
# Initial list of keywords to search for
initial_keywords = ['Macular', 'Degeneration']

# %%
# Function to extract words from a string (case-insensitive)
def extract_words(text):
    return re.findall(r'\b\w+\b', text.lower())  # Extract words and convert to lowercase

# %%
# Function to check if a word is a noun
def is_noun(word):
    # Tokenize and apply POS tagging
    pos_info = pos_tag(word_tokenize(word))
    
    # POS tag for noun starts with 'NN' (singular NN or plural NNS)
    return pos_info[0][1] in ['NN', 'NNS']

# Function to filter out nouns from a list of keywords
def filter_nouns(keywords):
    nouns = [word for word in keywords if is_noun(word)]
    return nouns

# Function to filter out nouns and specific words from a list of keywords
def filter_specific_words(keywords, specific_words):
    non_nouns = [word for word in keywords if word not in specific_words]
    return non_nouns

# %%
def search_keywords_recursive(df, keywords, all_found_keywords=None):
    if all_found_keywords is None:
        all_found_keywords = set()  # Track all found keywords to avoid endless loops

    # Convert keywords to lowercase for case-insensitive matching
    keywords_orig = [keyword.lower() for keyword in keywords]

    # Get the keywords that are not nouns
    keywords_nouns = filter_nouns(keywords_orig)

    # Specific words to remove
    specific_words = {'isn', 'm', 's'}
    keywords = filter_specific_words(keywords_nouns, specific_words)
    

    # Dictionary to store matches
    result = {}

    # Track new keywords to keep searching
    new_keywords = set()

    # Iterate through each keyword and search in both columns
    for keyword in keywords:
        # Skip keywords already fully searched
        if keyword in all_found_keywords:
            continue

        all_found_keywords.add(keyword)
        result[keyword] = {'Liverpool Diseases': [], 'Comments_LW': []}

        for col in ['Liverpool Diseases', 'Comments_LW']:
            # Handle NaN values by converting all values to strings before searching
            matching_rows = df[df[col].astype(str).str.lower().str.contains(keyword, na=False)]

            # Collect matching entries for these rows and extract new keywords
            if not matching_rows.empty:
                result[keyword][col] = matching_rows[col].tolist()

                # Extract words from the matching rows in both Liverpool Diseases and Comments_LW
                for row in matching_rows.itertuples():
                    col1_text = str(row[1])  # Convert Liverpool Diseases data to string
                    col2_text = str(row[2])  # Convert Comments_LW data to string

                    # Immediately add new keywords found in matching rows
                    new_keywords.update(extract_words(col1_text))
                    new_keywords.update(extract_words(col2_text))

    # Remove already searched keywords from the new keywords
    new_keywords -= all_found_keywords

    # If there are new keywords, perform the recursive search
    if new_keywords:
        further_results = search_keywords_recursive(df, list(new_keywords), all_found_keywords)

        # Combine results from the current iteration with recursive results
        for keyword, col_dict in further_results.items():
            if keyword in result:
                result[keyword]['Liverpool Diseases'].extend(col_dict['Liverpool Diseases'])
                result[keyword]['Comments_LWs_LW'].extend(col_dict['Comments_LW'])
            else:
                result[keyword] = col_dict

    return result

# %%
# Perform the recursive search
result = search_keywords_recursive(df_comments, initial_keywords)
result
# Out:
# {'macular': {'Liverpool Diseases': ['Macular Degeneration'],
#   'Comments_LW': []},
#  'degeneration': {'Liverpool Diseases': ['Macular Degeneration'],
#   'Comments_LW': []},
#  'nan': {'Liverpool Diseases': [],
#   'Comments_LW': [nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]},
#  'method': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'use': {'Liverpool Diseases': ['Psychoactive Substance Misuse'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness']},
#  'stage': {'Liverpool Diseases': ['End Stage Renal Disease'],
#   'Comments_LW': []},
#  'definition': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'copd': {'Liverpool Diseases': ['Chronic Obstructive Pulmonary Disease (COPD)'],
#   'Comments_LW': []},
#  'management': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'thyroid': {'Liverpool Diseases': ['Hyperparathyroidism', 'Thyroid Problem'],
#   'Comments_LW': []},
#  'hypotension': {'Liverpool Diseases': [],
#   'Comments_LW': ['covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check']},
#  'consistency': {'Liverpool Diseases': [],
#   'Comments_LW': ['need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ']},
#  'foot': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'cognitive': {'Liverpool Diseases': [],
#   'Comments_LW': ['compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare']},
#  'lists': {'Liverpool Diseases': [],
#   'Comments_LW': ['feature in both, can someone check both code lists to confirm they are the same?',
#    'need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'in eFI, can someone check and compare the code lists?',
#    'in eFI, can someone check and compare the code lists?',
#    'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'merge codes lists',
#    'prbably covered within back pain list - merge code lists under "back pain"',
#    'compare code lists',
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists",
#    'compare and merge lists',
#    'compare code lists',
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists',
#    'combine code lists for valve disorders',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity',
#    'compare and merge lists',
#    'compare and merge lists',
#    'compare and merge lists',
#    'can merge all the valve disorder lists',
#    'compare with eFI visual impairment list and merge lists']},
#  'way': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'housebound': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'problems': {'Liverpool Diseases': [],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'covered by "toileting problems" in eFI',
#    'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check',
#    'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list',
#    "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding",
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']},
#  'heart': {'Liverpool Diseases': ['Coronary Heart Disease', 'Heart Failure'],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'could combine into "heart block"',
#    'probably included under the "heart failure" code list but can someone check please?',
#    'compare with eFI ischaemic heart disease list',
#    'probably contained within ischemic heart disease list, can be merged',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'see comments re ischaemic heart disease list']},
#  'list': {'Liverpool Diseases': ['Spondylolisthesis'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'Keep this - not currently covered by eFI list',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation',
#    'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)',
#    'Keep this - not currently covered by eFI list',
#    'feature in both, can someone check both code lists to confirm they are the same?',
#    'need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'Keep this - not currently covered by eFI list',
#    'probably included under the "heart failure" code list but can someone check please?',
#    'probably included under the visual impairment code list but please check and if not, include',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can join the benign tumours list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'in eFI, can someone check and compare the code lists?',
#    'in eFI, can someone check and compare the code lists?',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI ischaemic heart disease list',
#    'Keep this - not currently covered by eFI list',
#    'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'Keep this - not currently covered by eFI list',
#    'can join the benign conditions list',
#    'Keep this - not currently covered by eFI list',
#    'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check',
#    'can join the benign tumours list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably contained within "stroke" code list in eFI but check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'can join benign conditions list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably covered by vision impairment list, please check',
#    'Keep this - not currently covered by eFI list',
#    'can join benign conditions list',
#    'Keep this - not currently covered by eFI list',
#    'merge codes lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably contained within ischemic heart disease list, can be merged',
#    'can be merged into single "valve disorders" list',
#    'compare to eFI list',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    'Keep this - not currently covered by eFI list',
#    'prbably covered within back pain list - merge code lists under "back pain"',
#    'compare code lists',
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists",
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'compare code lists',
#    'Keep this - not currently covered by eFI list and important for mental health focus',
#    'Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'I think we need a new code list for "benign polyps" and put all the polyp coodes together',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'combine code lists for valve disorders',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'compare and merge lists',
#    'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'see comments re ischaemic heart disease list',
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can merge all the valve disorder lists',
#    'compare with eFI visual impairment list and merge lists',
#    'Keep this - not currently covered by eFI list']},
#  'determination': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'code': {'Liverpool Diseases': [],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'feature in both, can someone check both code lists to confirm they are the same?',
#    'need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'probably included under the "heart failure" code list but can someone check please?',
#    'probably included under the visual impairment code list but please check and if not, include',
#    'in eFI, can someone check and compare the code lists?',
#    'in eFI, can someone check and compare the code lists?',
#    'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes',
#    'compare with eFI code list',
#    'compare with eFI code list',
#    'probably contained within "stroke" code list in eFI but check',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'merge codes lists',
#    'prbably covered within back pain list - merge code lists under "back pain"',
#    'compare code lists',
#    'compare code lists',
#    'I think we need a new code list for "benign polyps" and put all the polyp coodes together',
#    'combine code lists for valve disorders',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out']},
#  'impairment': {'Liverpool Diseases': ['Visual Impairment and Blindness'],
#   'Comments_LW': ['not covered by eFI, there is a visual impairment heading ',
#    'probably included under the visual impairment code list but please check and if not, include',
#    'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes',
#    'merge with "hearing impairment" from eFI',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'probably covered by vision impairment list, please check',
#    'compare with eFI visual impairment list and merge lists']},
#  'medication': {'Liverpool Diseases': [],
#   'Comments_LW': ['eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ']},
#  'need': {'Liverpool Diseases': [],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes',
#    'I think we need a new code list for "benign polyps" and put all the polyp coodes together',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']},
#  'defines': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'include': {'Liverpool Diseases': [],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    "I don't mind if we don't include this",
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'I would separate PD tremor from benign tremor (included together in eFI)',
#    'probably included under the "heart failure" code list but can someone check please?',
#    'probably included under the visual impairment code list but please check and if not, include']},
#  'syncope': {'Liverpool Diseases': [],
#   'Comments_LW': ['covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check']},
#  'fibrillation': {'Liverpool Diseases': ['Atrial Fibrillation'],
#   'Comments_LW': []},
#  'compare': {'Liverpool Diseases': [],
#   'Comments_LW': ['need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'in eFI, can someone check and compare the code lists?',
#    'in eFI, can someone check and compare the code lists?',
#    'compare with eFI ischaemic heart disease list',
#    'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'compare to eFI  ',
#    'compare with eFI code list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'compare to eFI list',
#    'compare code lists',
#    'compare and merge lists',
#    'compare code lists',
#    'compare and merge lists',
#    'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out',
#    'compare and merge lists',
#    'compare and merge lists',
#    'compare with eFI visual impairment list and merge lists']},
#  'chronic': {'Liverpool Diseases': ['Allergic And Chronic rhinitis',
#    'Chronic constipation',
#    'Chronic Dermatitis Eczema',
#    'Chronic Fatigue Syndrome',
#    'Chronic Kidney Disease',
#    'Chronic Liver disease And Viral hepatitis',
#    'Chronic Obstructive Pulmonary Disease (COPD)',
#    'Chronic pain',
#    'Chronic Pancreatitis',
#    'Chronic Sinusitis',
#    'Chronic Tinnitus',
#    'Chronic Urticaria'],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)',
#    'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ',
#    'not strictly a chronic condition and we could remove this']},
#  'investigations': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'failure': {'Liverpool Diseases': ['Heart Failure'],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'probably included under the "heart failure" code list but can someone check please?']},
#  'cons': {'Liverpool Diseases': ['Chronic constipation'],
#   'Comments_LW': ['need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ']},
#  'hypertension': {'Liverpool Diseases': ['Hypertension',
#    'INTRACRANIALHypertension',
#    'PRIMARYPULMONARYHypertension',
#    'SECONDARYPULMONARYHypertension'],
#   'Comments_LW': []},
#  'disease': {'Liverpool Diseases': ['Alcoholic Liver Disease',
#    'Autoimmune liver Disease',
#    'Chronic Kidney Disease',
#    'Chronic Liver disease And Viral hepatitis',
#    'Chronic Obstructive Pulmonary Disease (COPD)',
#    'Coeliac Disease',
#    'Coronary Heart Disease',
#    'Diabetic eye disease',
#    'Diverticular Disease',
#    'End Stage Renal Disease',
#    'Gastrooesophageal Reflux Disease',
#    'Inflammatory Bowel Disease Crohn Disease',
#    'Inflammatory Bowel Disease Ulcerative Colitis',
#    'Meniere Disease',
#    'Motor neurone Disease (MND)',
#    'Ovarian Cystic Disease',
#    'Parkinson Disease',
#    'Peptic ulcer Disease',
#    'Peripheral Vascular Disease',
#    'Rheumatic Valve disease',
#    'Sjogren Disease'],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'compare with eFI ischaemic heart disease list',
#    'probably contained within ischemic heart disease list, can be merged',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'see comments re ischaemic heart disease list']},
#  'pros': {'Liverpool Diseases': ['Prostate Disorder'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']},
#  'liv': {'Liverpool Diseases': ['Alcoholic Liver Disease',
#    'Autoimmune liver Disease',
#    'Chronic Liver disease And Viral hepatitis',
#    'Fatty Liver'],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else',
#    'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ',
#    'I would like these 3 to be separate but I can live with lumping them all together under a diabetes umbrella',
#    'brain haemangiomas can be a problem if not addressed in childhood but as we are focusing on adulthood I could live with removing this']},
#  'pain': {'Liverpool Diseases': ['Chronic pain'],
#   'Comments_LW': ['eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ',
#    'covered by back pain so this could be retitled to "back pain"',
#    'prbably covered within back pain list - merge code lists under "back pain"']},
#  'valve': {'Liverpool Diseases': ['Non-rheumatic Aortic Valve Disorders',
#    'Non-rheumatic Mitral Valve Disorders',
#    'Rheumatic Valve disease',
#    'Valve disorder non-rheumatic multiple'],
#   'Comments_LW': ['can be merged into single "valve disorders" list',
#    'combine code lists for valve disorders',
#    'can merge all the valve disorder lists']},
#  'kidney': {'Liverpool Diseases': ['Chronic Kidney Disease'],
#   'Comments_LW': []},
#  'limitation': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'palliative': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'seizure': {'Liverpool Diseases': [],
#   'Comments_LW': ['we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything']},
#  'musculoskeletal': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'health': {'Liverpool Diseases': [],
#   'Comments_LW': ['covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    'Keep this - not currently covered by eFI list and important for mental health focus']},
#  'obesity': {'Liverpool Diseases': ['Obesity'], 'Comments_LW': []},
#  'attack': {'Liverpool Diseases': ['Transient Ischaemic Attack'],
#   'Comments_LW': []},
#  'self': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'efi': {'Liverpool Diseases': ['Anaemia Folate Deficiency',
#    'Attention Deficit Hyperactivity Disorder',
#    'Immunodeficiencies'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation',
#    'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)',
#    'Keep this - not currently covered by eFI list',
#    'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out',
#    'not covered by eFI, there is a visual impairment heading ',
#    "not in eFI, I'd like to keep it",
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'Keep this - not currently covered by eFI list',
#    'I would separate PD tremor from benign tremor (included together in eFI)',
#    'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate',
#    'covered by "toileting problems" in eFI',
#    'Keep this - not currently covered by eFI list',
#    'my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'in eFI, can someone check and compare the code lists?',
#    'in eFI, can someone check and compare the code lists?',
#    'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI ischaemic heart disease list',
#    'Keep this - not currently covered by eFI list',
#    'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'compare to eFI  ',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'merge with "hearing impairment" from eFI',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably contained within "stroke" code list in eFI but check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare to eFI list',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    'Keep this - not currently covered by eFI list',
#    "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding",
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists",
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list and important for mental health focus',
#    'Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI visual impairment list and merge lists',
#    'Keep this - not currently covered by eFI list']},
#  't': {'Liverpool Diseases': ['Abdominal Aortic Aneurysm',
#    'Acoustic Neuroma',
#    'Actinic keratosis',
#    'Alcohol-related Brain Injury',
#    'Allergic And Chronic rhinitis',
#    'Alopecia Areata',
#    'Anaemia Aplastic',
#    'Anaemia Folate Deficiency',
#    'Anaemia Haemolytic',
#    'Ankylosing Spondylitis',
#    'Anorectal Prolapse',
#    'Anterior and Intermediate Uveitis',
#    'Anxiety',
#    'Asbestosis',
#    'Asthma',
#    'Atrial Fibrillation',
#    'Atrioventricular Block Complete',
#    'Atrioventricular Block Second Degree',
#    'Attention Deficit Hyperactivity Disorder',
#    'Autism and Asperger Syndrome',
#    'Autoimmune liver Disease',
#    'Barrett Oesophagus',
#    'Benign neoplasm Aortic carotid Body Neuroendocrine',
#    'Benign neoplasm Central nervous System',
#    'Benign neoplasm Gastrointestinal Tract',
#    'Benign tremor',
#    'Bipolar affective Disorder and Mania',
#    'Bladder Dysfunction',
#    'Bronchiectasis',
#    'Cancer Haematological',
#    'Carcinoma in situ_Cervical',
#    'Cardiomyopathy other',
#    'Cataract',
#    'Cholelithiasis',
#    'Chronic constipation',
#    'Chronic Dermatitis Eczema',
#    'Chronic Fatigue Syndrome',
#    'Chronic Liver disease And Viral hepatitis',
#    'Chronic Obstructive Pulmonary Disease (COPD)',
#    'Chronic Pancreatitis',
#    'Chronic Sinusitis',
#    'Chronic Tinnitus',
#    'Chronic Urticaria',
#    'Coronary Heart Disease',
#    'Corpus Luteum cyst',
#    'Cystic Fibrosis',
#    'Dementia',
#    'Dermatitis atopic contact',
#    'Dermoid cyst Of Ovary',
#    'Diabetes',
#    'Diabetic eye disease',
#    'Diabetic Neuropathy',
#    'Dilated Cardiomyopathy',
#    'Disorders of Autonomic Nervous System',
#    'Diverticular Disease',
#    'End Stage Renal Disease',
#    'Endometrial Hyperplasia and Hypertrophy',
#    'Endometriosis',
#    'Erectile Dysfunction',
#    'Essential Tremor',
#    'Fatty Liver',
#    'Female genital Prolapse',
#    'Fibromatoses',
#    'Gastritis and Duodenitis',
#    'Gastrooesophageal Reflux Disease',
#    'Glomerulonephritis',
#    'Gout',
#    'Haemangioma any site',
#    'Heart Failure',
#    'Hyperparathyroidism',
#    'Hypertension',
#    'Hypertrophic Cardiomyopathy',
#    'Hypertrophy of Nasal Turbinates',
#    'Inflammatory Bowel Disease Crohn Disease',
#    'Inflammatory Bowel Disease Ulcerative Colitis',
#    'Intracerebral Haemorrhage',
#    'INTRACRANIALHypertension',
#    'Irritable Bowel Syndrome',
#    'Learning Disability',
#    'Leiomyoma of Uterus',
#    'Lupus Erythematosus',
#    'Macular Degeneration',
#    'Motor neurone Disease (MND)',
#    'Multiple Sclerosis',
#    'Myasthenia Gravis',
#    'Myocardial Infarction',
#    'Non-rheumatic Aortic Valve Disorders',
#    'Non-rheumatic Mitral Valve Disorders',
#    'Obesity',
#    'Obstructive Sleep Apnoea',
#    'Osteoarthritis excluding spine',
#    'Osteoporosis',
#    'Ovarian Cystic Disease',
#    'Peptic ulcer Disease',
#    'Peripheral Neuropathies Excluding Cranial nerve and carpal tunnel syndrome',
#    'Personality Disorder',
#    'Pituitary adenoma',
#    'Polycystic Ovarian Syndrome',
#    'Polycythaemia vera',
#    'Polymyalgia Rheumatica',
#    'Primary Idiopathic Thrombocytopaenia',
#    'PRIMARYPULMONARYHypertension',
#    'Prostate Disorder',
#    'Psoriatic Arthropathy',
#    'Psychoactive Substance Misuse',
#    'Recurrent pulmonary embolus',
#    'Renal Stones',
#    'Rheumatic Valve disease',
#    'Rheumatoid Arthritis',
#    'Secondary Polycythaemia',
#    'SECONDARYPULMONARYHypertension',
#    'Spinal stenosis',
#    'Spondylolisthesis',
#    'Stable Angina',
#    'Stroke CVA',
#    'Subdural Haematoma no-traumatic',
#    'Systemic Sclerosis',
#    'Thalassaemia',
#    'Thrombophilia',
#    'Thyroid Problem',
#    'Transient Ischaemic Attack',
#    'Tuberculosis',
#    'UnStable Angina',
#    'Urinary Incontinence',
#    'Urolithiasis',
#    'Uterovaginal Genital Prolapse',
#    'Valve disorder non-rheumatic multiple',
#    'Visual Impairment and Blindness',
#    'Vitiligo'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'benign tumour - we could put all benign tumours into a single category if preferable?',
#    'Keep this - not currently covered by eFI list',
#    'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'Keep this - not currently covered by eFI list',
#    "I don't mind if we don't include this",
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation',
#    'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)',
#    'Keep this - not currently covered by eFI list',
#    'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out',
#    'not covered by eFI, there is a visual impairment heading ',
#    'feature in both, can someone check both code lists to confirm they are the same?',
#    "not in eFI, I'd like to keep it",
#    'need to compare code lists for consistency. ',
#    'need to compare code lists for consistency. ',
#    'could combine into "heart block"',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'Keep this - not currently covered by eFI list',
#    'we can merge all the benign tumours into a single "benign tumour" category',
#    'I would separate PD tremor from benign tremor (included together in eFI)',
#    'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate',
#    'covered by "toileting problems" in eFI',
#    'Keep this - not currently covered by eFI list',
#    'my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'Keep this - not currently covered by eFI list',
#    'probably included under the "heart failure" code list but can someone check please?',
#    'probably included under the visual impairment code list but please check and if not, include',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can join the benign tumours list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'in eFI, can someone check and compare the code lists?',
#    'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else',
#    'in eFI, can someone check and compare the code lists?',
#    'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI ischaemic heart disease list',
#    'Keep this - not currently covered by eFI list',
#    'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI',
#    'compare to eFI  ',
#    'Keep this - not currently covered by eFI list',
#    'can join the benign conditions list',
#    'I would like these 3 to be separate but I can live with lumping them all together under a diabetes umbrella',
#    'Keep this - not currently covered by eFI list',
#    'covered by back pain so this could be retitled to "back pain"',
#    'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'I would prefer to have this seperated from general CKD if possible',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'Keep this - not currently covered by eFI list',
#    'can go under "tremor"',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check',
#    'can join the benign tumours list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list',
#    'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes',
#    'Keep this - not currently covered by eFI list',
#    'brain haemangiomas can be a problem if not addressed in childhood but as we are focusing on adulthood I could live with removing this',
#    'merge with "hearing impairment" from eFI',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can be merged into IBD',
#    'probably contained within "stroke" code list in eFI but check',
# ...
#    'Keep this - not currently covered by eFI list',
#    'I would prefer to have this seperated from general CKD if possible',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'Keep this - not currently covered by eFI list',
#    'can go under "tremor"',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list',
#    'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes',
#    'Keep this - not currently covered by eFI list',
#    'brain haemangiomas can be a problem if not addressed in childhood but as we are focusing on adulthood I could live with removing this',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare with eFI code list',
#    'Keep this - not currently covered by eFI list',
#    'can be removed',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can be merged into IBD',
#    'probably contained within "stroke" code list in eFI but check',
#    'can be removed',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare',
#    'can join benign conditions list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably covered by vision impairment list, please check',
#    'Keep this - not currently covered by eFI list',
#    'can join benign conditions list',
#    'Keep this - not currently covered by eFI list',
#    'probably covered by "headache" but I would prefer to separate as it is independent stroke risk',
#    'merge codes lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'probably contained within ischemic heart disease list, can be merged',
#    'can be removed',
#    'can be merged into single "valve disorders" list',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    'Keep this - not currently covered by eFI list',
#    "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding",
#    'prbably covered within back pain list - merge code lists under "back pain"',
#    'compare code lists',
#    'benign, can be removed and just keep polycystic ovarian (pcos)',
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists",
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'compare code lists',
#    'Keep this - not currently covered by eFI list and important for mental health focus',
#    'Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness',
#    'not strictly a chronic condition and we could remove this',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'I think we need a new code list for "benign polyps" and put all the polyp coodes together',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'combine code lists for valve disorders',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate',
#    'compare and merge lists',
#    'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'see comments re ischaemic heart disease list',
#    'compare and merge lists',
#    'Keep this - not currently covered by eFI list',
#    'Keep this - not currently covered by eFI list',
#    'can merge all the valve disorder lists',
#    'compare with eFI visual impairment list and merge lists',
#    'Keep this - not currently covered by eFI list']},
#  'asthma': {'Liverpool Diseases': ['Asthma'], 'Comments_LW': []},
#  'pref': {'Liverpool Diseases': [],
#   'Comments_LW': ['benign tumour - we could put all benign tumours into a single category if preferable?',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out',
#    'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate',
#    'my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'I would prefer to have this seperated from general CKD if possible',
#    'probably covered by "headache" but I would prefer to separate as it is independent stroke risk',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding",
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists"]},
#  'incontinence': {'Liverpool Diseases': ['Urinary Incontinence'],
#   'Comments_LW': []},
#  'cancer': {'Liverpool Diseases': ['Cancer Haematological',
#    'Cancer Solid organ'],
#   'Comments_LW': ['my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']},
#  'vascular': {'Liverpool Diseases': ['Peripheral Vascular Disease'],
#   'Comments_LW': []},
#  'chronicity': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'mass': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'neuron': {'Liverpool Diseases': ['Motor neurone Disease (MND)'],
#   'Comments_LW': []},
#  'transient': {'Liverpool Diseases': ['Transient Ischaemic Attack'],
#   'Comments_LW': []},
#  'prefer': {'Liverpool Diseases': [],
#   'Comments_LW': ['benign tumour - we could put all benign tumours into a single category if preferable?',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out',
#    'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate',
#    'my preference is to separate out the cancers and not have a single cancer list like in eFI',
#    'I would prefer to have this seperated from general CKD if possible',
#    'probably covered by "headache" but I would prefer to separate as it is independent stroke risk',
#    'may be covered by "general mental health" eFI list but I\'d prefer to separate',
#    "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding",
#    "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists"]},
#  'mean': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'outcomes': {'Liverpool Diseases': [],
#   'Comments_LW': ['Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']},
#  'deficit': {'Liverpool Diseases': ['Attention Deficit Hyperactivity Disorder'],
#   'Comments_LW': []},
#  'disorders': {'Liverpool Diseases': ['Disc Disorders',
#    'Disorders of Autonomic Nervous System',
#    'Non-rheumatic Aortic Valve Disorders',
#    'Non-rheumatic Mitral Valve Disorders'],
#   'Comments_LW': ['we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything',
#    'can be merged into single "valve disorders" list',
#    'combine code lists for valve disorders']},
#  'concerns': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'comapre': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'weakness': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'distinct': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'liver': {'Liverpool Diseases': ['Alcoholic Liver Disease',
#    'Autoimmune liver Disease',
#    'Chronic Liver disease And Viral hepatitis',
#    'Fatty Liver'],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes',
#    'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one',
#    'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease',
#    'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else']},
#  'headache': {'Liverpool Diseases': [],
#   'Comments_LW': ['probably covered by "headache" but I would prefer to separate as it is independent stroke risk']},
#  'loss': {'Liverpool Diseases': ['Hearing loss'],
#   'Comments_LW': ['not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list']},
#  'injury': {'Liverpool Diseases': ['Alcohol-related Brain Injury'],
#   'Comments_LW': ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes']},
#  'liverpool': {'Liverpool Diseases': [],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']},
#  'fatigue': {'Liverpool Diseases': ['Chronic Fatigue Syndrome'],
#   'Comments_LW': []},
#  'mono': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'respiratory': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'motor': {'Liverpool Diseases': ['Motor neurone Disease (MND)'],
#   'Comments_LW': []},
#  'sleep': {'Liverpool Diseases': ['Obstructive Sleep Apnoea'],
#   'Comments_LW': []},
#  'vulnerability': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'bowel': {'Liverpool Diseases': ['Inflammatory Bowel Disease Crohn Disease',
#    'Inflammatory Bowel Disease Ulcerative Colitis',
#    'Irritable Bowel Syndrome'],
#   'Comments_LW': []},
#  'environment': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'anaemia': {'Liverpool Diseases': ['Anaemia Aplastic',
#    'Anaemia Folate Deficiency',
#    'Anaemia Haemolytic',
#    'Anaemia Nos',
#    'Sickle cell anaemia'],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']},
#  'dizziness': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'uc': {'Liverpool Diseases': ['Chronic Obstructive Pulmonary Disease (COPD)',
#    'Glaucoma',
#    'Obstructive Sleep Apnoea'],
#   'Comments_LW': ['Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness',
#    'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']},
#  'detail': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'crohns': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'deficiency': {'Liverpool Diseases': ['Anaemia Folate Deficiency'],
#   'Comments_LW': []},
#  'headings': {'Liverpool Diseases': [],
#   'Comments_LW': ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']},
#  'haematinic': {'Liverpool Diseases': [], 'Comments_LW': []},
#  'hearing': {'Liverpool Diseases': ['Hearing loss'],
#   'Comments_LW': ['merge with "hearing impairment" from eFI']},
#  'skin': {'Liverpool Diseases': [], 'Comments_LW': []}}

# %%
# Output the result
for keyword, columns in result.items():
    print(f"Keyword '{keyword}' found in:")
    for col, entries in columns.items():
        print(f"  {col}: {entries}")
# Out:
# Keyword 'macular' found in:
#   Liverpool Diseases: ['Macular Degeneration']
#   Comments_LW: []
# Keyword 'degeneration' found in:
#   Liverpool Diseases: ['Macular Degeneration']
#   Comments_LW: []
# Keyword 'nan' found in:
#   Liverpool Diseases: []
#   Comments_LW: [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# Keyword 'method' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'use' found in:
#   Liverpool Diseases: ['Psychoactive Substance Misuse']
#   Comments_LW: ['Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness']
# Keyword 'stage' found in:
#   Liverpool Diseases: ['End Stage Renal Disease']
#   Comments_LW: []
# Keyword 'definition' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'copd' found in:
#   Liverpool Diseases: ['Chronic Obstructive Pulmonary Disease (COPD)']
#   Comments_LW: []
# Keyword 'management' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'thyroid' found in:
#   Liverpool Diseases: ['Hyperparathyroidism', 'Thyroid Problem']
#   Comments_LW: []
# Keyword 'hypotension' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check']
# Keyword 'consistency' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['need to compare code lists for consistency. ', 'need to compare code lists for consistency. ']
# Keyword 'foot' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'cognitive' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare']
# Keyword 'lists' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['feature in both, can someone check both code lists to confirm they are the same?', 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'in eFI, can someone check and compare the code lists?', 'in eFI, can someone check and compare the code lists?', 'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'merge codes lists', 'prbably covered within back pain list - merge code lists under "back pain"', 'compare code lists', "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists", 'compare and merge lists', 'compare code lists', 'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists', 'combine code lists for valve disorders', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity', 'compare and merge lists', 'compare and merge lists', 'compare and merge lists', 'can merge all the valve disorder lists', 'compare with eFI visual impairment list and merge lists']
# Keyword 'way' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'housebound' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'problems' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'covered by "toileting problems" in eFI', 'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check', 'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list', "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding", 'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']
# Keyword 'heart' found in:
#   Liverpool Diseases: ['Coronary Heart Disease', 'Heart Failure']
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'could combine into "heart block"', 'probably included under the "heart failure" code list but can someone check please?', 'compare with eFI ischaemic heart disease list', 'probably contained within ischemic heart disease list, can be merged', 'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate', 'see comments re ischaemic heart disease list']
# Keyword 'list' found in:
#   Liverpool Diseases: ['Spondylolisthesis']
#   Comments_LW: ['Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'Keep this - not currently covered by eFI list', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation', 'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'Keep this - not currently covered by eFI list', 'feature in both, can someone check both code lists to confirm they are the same?', 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'Keep this - not currently covered by eFI list', 'probably included under the "heart failure" code list but can someone check please?', 'probably included under the visual impairment code list but please check and if not, include', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'can join the benign tumours list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'in eFI, can someone check and compare the code lists?', 'in eFI, can someone check and compare the code lists?', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'compare with eFI ischaemic heart disease list', 'Keep this - not currently covered by eFI list', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'Keep this - not currently covered by eFI list', 'can join the benign conditions list', 'Keep this - not currently covered by eFI list', 'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check', 'can join the benign tumours list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list', 'Keep this - not currently covered by eFI list', 'compare with eFI code list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered  ...
# Keyword 'determination' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'code' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'feature in both, can someone check both code lists to confirm they are the same?', 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'probably included under the "heart failure" code list but can someone check please?', 'probably included under the visual impairment code list but please check and if not, include', 'in eFI, can someone check and compare the code lists?', 'in eFI, can someone check and compare the code lists?', 'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes', 'compare with eFI code list', 'compare with eFI code list', 'probably contained within "stroke" code list in eFI but check', 'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare', 'merge codes lists', 'prbably covered within back pain list - merge code lists under "back pain"', 'compare code lists', 'compare code lists', 'I think we need a new code list for "benign polyps" and put all the polyp coodes together', 'combine code lists for valve disorders', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity', 'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check', 'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate', 'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out']
# Keyword 'impairment' found in:
#   Liverpool Diseases: ['Visual Impairment and Blindness']
#   Comments_LW: ['not covered by eFI, there is a visual impairment heading ', 'probably included under the visual impairment code list but please check and if not, include', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes', 'merge with "hearing impairment" from eFI', 'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare', 'probably covered by vision impairment list, please check', 'compare with eFI visual impairment list and merge lists']
# Keyword 'medication' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ']
# Keyword 'need' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes', 'I think we need a new code list for "benign polyps" and put all the polyp coodes together', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']
# Keyword 'defines' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'include' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', "I don't mind if we don't include this", 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'I would separate PD tremor from benign tremor (included together in eFI)', 'probably included under the "heart failure" code list but can someone check please?', 'probably included under the visual impairment code list but please check and if not, include']
# Keyword 'syncope' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check']
# Keyword 'fibrillation' found in:
#   Liverpool Diseases: ['Atrial Fibrillation']
#   Comments_LW: []
# Keyword 'compare' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'in eFI, can someone check and compare the code lists?', 'in eFI, can someone check and compare the code lists?', 'compare with eFI ischaemic heart disease list', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'compare to eFI  ', 'compare with eFI code list', 'compare with eFI code list', 'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare', 'compare to eFI list', 'compare code lists', 'compare and merge lists', 'compare code lists', 'compare and merge lists', 'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out', 'compare and merge lists', 'compare and merge lists', 'compare with eFI visual impairment list and merge lists']
# Keyword 'chronic' found in:
#   Liverpool Diseases: ['Allergic And Chronic rhinitis', 'Chronic constipation', 'Chronic Dermatitis Eczema', 'Chronic Fatigue Syndrome', 'Chronic Kidney Disease', 'Chronic Liver disease And Viral hepatitis', 'Chronic Obstructive Pulmonary Disease (COPD)', 'Chronic pain', 'Chronic Pancreatitis', 'Chronic Sinusitis', 'Chronic Tinnitus', 'Chronic Urticaria']
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'not strictly a chronic condition and we could remove this']
# Keyword 'investigations' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'failure' found in:
#   Liverpool Diseases: ['Heart Failure']
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'probably included under the "heart failure" code list but can someone check please?']
# Keyword 'cons' found in:
#   Liverpool Diseases: ['Chronic constipation']
#   Comments_LW: ['need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ']
# Keyword 'hypertension' found in:
#   Liverpool Diseases: ['Hypertension', 'INTRACRANIALHypertension', 'PRIMARYPULMONARYHypertension', 'SECONDARYPULMONARYHypertension']
#   Comments_LW: []
# Keyword 'disease' found in:
#   Liverpool Diseases: ['Alcoholic Liver Disease', 'Autoimmune liver Disease', 'Chronic Kidney Disease', 'Chronic Liver disease And Viral hepatitis', 'Chronic Obstructive Pulmonary Disease (COPD)', 'Coeliac Disease', 'Coronary Heart Disease', 'Diabetic eye disease', 'Diverticular Disease', 'End Stage Renal Disease', 'Gastrooesophageal Reflux Disease', 'Inflammatory Bowel Disease Crohn Disease', 'Inflammatory Bowel Disease Ulcerative Colitis', 'Meniere Disease', 'Motor neurone Disease (MND)', 'Ovarian Cystic Disease', 'Parkinson Disease', 'Peptic ulcer Disease', 'Peripheral Vascular Disease', 'Rheumatic Valve disease', 'Sjogren Disease']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'compare with eFI ischaemic heart disease list', 'probably contained within ischemic heart disease list, can be merged', 'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate', 'see comments re ischaemic heart disease list']
# Keyword 'pros' found in:
#   Liverpool Diseases: ['Prostate Disorder']
#   Comments_LW: ['Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']
# Keyword 'liv' found in:
#   Liverpool Diseases: ['Alcoholic Liver Disease', 'Autoimmune liver Disease', 'Chronic Liver disease And Viral hepatitis', 'Fatty Liver']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'I would like these 3 to be separate but I can live with lumping them all together under a diabetes umbrella', 'brain haemangiomas can be a problem if not addressed in childhood but as we are focusing on adulthood I could live with removing this']
# Keyword 'pain' found in:
#   Liverpool Diseases: ['Chronic pain']
#   Comments_LW: ['eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'covered by back pain so this could be retitled to "back pain"', 'prbably covered within back pain list - merge code lists under "back pain"']
# Keyword 'valve' found in:
#   Liverpool Diseases: ['Non-rheumatic Aortic Valve Disorders', 'Non-rheumatic Mitral Valve Disorders', 'Rheumatic Valve disease', 'Valve disorder non-rheumatic multiple']
#   Comments_LW: ['can be merged into single "valve disorders" list', 'combine code lists for valve disorders', 'can merge all the valve disorder lists']
# Keyword 'kidney' found in:
#   Liverpool Diseases: ['Chronic Kidney Disease']
#   Comments_LW: []
# Keyword 'limitation' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'palliative' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'seizure' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything']
# Keyword 'musculoskeletal' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'health' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'may be covered by "general mental health" eFI list but I\'d prefer to separate', 'Keep this - not currently covered by eFI list and important for mental health focus']
# Keyword 'obesity' found in:
#   Liverpool Diseases: ['Obesity']
#   Comments_LW: []
# Keyword 'attack' found in:
#   Liverpool Diseases: ['Transient Ischaemic Attack']
#   Comments_LW: []
# Keyword 'self' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'efi' found in:
#   Liverpool Diseases: ['Anaemia Folate Deficiency', 'Attention Deficit Hyperactivity Disorder', 'Immunodeficiencies']
#   Comments_LW: ['Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation', 'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'Keep this - not currently covered by eFI list', 'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'not covered by eFI, there is a visual impairment heading ', "not in eFI, I'd like to keep it", 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'Keep this - not currently covered by eFI list', 'I would separate PD tremor from benign tremor (included together in eFI)', 'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'covered by "toileting problems" in eFI', 'Keep this - not currently covered by eFI list', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'in eFI, can someone check and compare the code lists?', 'in eFI, can someone check and compare the code lists?', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'compare with eFI ischaemic heart disease list', 'Keep this - not currently covered by eFI list', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'compare to eFI  ', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'covered by "hypotension/syncope" in eFI so wa can call it that and merge the code lists', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list unless it comes under bladder problems, please check', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'merge with "hearing impairment" from eFI', 'compare with eFI code list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'compare with eFI code list', 'Ke ...
# Keyword 't' found in:
#   Liverpool Diseases: ['Abdominal Aortic Aneurysm', 'Acoustic Neuroma', 'Actinic keratosis', 'Alcohol-related Brain Injury', 'Allergic And Chronic rhinitis', 'Alopecia Areata', 'Anaemia Aplastic', 'Anaemia Folate Deficiency', 'Anaemia Haemolytic', 'Ankylosing Spondylitis', 'Anorectal Prolapse', 'Anterior and Intermediate Uveitis', 'Anxiety', 'Asbestosis', 'Asthma', 'Atrial Fibrillation', 'Atrioventricular Block Complete', 'Atrioventricular Block Second Degree', 'Attention Deficit Hyperactivity Disorder', 'Autism and Asperger Syndrome', 'Autoimmune liver Disease', 'Barrett Oesophagus', 'Benign neoplasm Aortic carotid Body Neuroendocrine', 'Benign neoplasm Central nervous System', 'Benign neoplasm Gastrointestinal Tract', 'Benign tremor', 'Bipolar affective Disorder and Mania', 'Bladder Dysfunction', 'Bronchiectasis', 'Cancer Haematological', 'Carcinoma in situ_Cervical', 'Cardiomyopathy other', 'Cataract', 'Cholelithiasis', 'Chronic constipation', 'Chronic Dermatitis Eczema', 'Chronic Fatigue Syndrome', 'Chronic Liver disease And Viral hepatitis', 'Chronic Obstructive Pulmonary Disease (COPD)', 'Chronic Pancreatitis', 'Chronic Sinusitis', 'Chronic Tinnitus', 'Chronic Urticaria', 'Coronary Heart Disease', 'Corpus Luteum cyst', 'Cystic Fibrosis', 'Dementia', 'Dermatitis atopic contact', 'Dermoid cyst Of Ovary', 'Diabetes', 'Diabetic eye disease', 'Diabetic Neuropathy', 'Dilated Cardiomyopathy', 'Disorders of Autonomic Nervous System', 'Diverticular Disease', 'End Stage Renal Disease', 'Endometrial Hyperplasia and Hypertrophy', 'Endometriosis', 'Erectile Dysfunction', 'Essential Tremor', 'Fatty Liver', 'Female genital Prolapse', 'Fibromatoses', 'Gastritis and Duodenitis', 'Gastrooesophageal Reflux Disease', 'Glomerulonephritis', 'Gout', 'Haemangioma any site', 'Heart Failure', 'Hyperparathyroidism', 'Hypertension', 'Hypertrophic Cardiomyopathy', 'Hypertrophy of Nasal Turbinates', 'Inflammatory Bowel Disease Crohn Disease', 'Inflammatory Bowel Disease Ulcerative Colitis', 'Intracerebral Haemorrhage', 'INTRACRANIALHypertension', 'Irritable Bowel Syndrome', 'Learning Disability', 'Leiomyoma of Uterus', 'Lupus Erythematosus', 'Macular Degeneration', 'Motor neurone Disease (MND)', 'Multiple Sclerosis', 'Myasthenia Gravis', 'Myocardial Infarction', 'Non-rheumatic Aortic Valve Disorders', 'Non-rheumatic Mitral Valve Disorders', 'Obesity', 'Obstructive Sleep Apnoea', 'Osteoarthritis excluding spine', 'Osteoporosis', 'Ovarian Cystic Disease', 'Peptic ulcer Disease', 'Peripheral Neuropathies Excluding Cranial nerve and carpal tunnel syndrome', 'Personality Disorder', 'Pituitary adenoma', 'Polycystic Ovarian Syndrome', 'Polycythaemia vera', 'Polymyalgia Rheumatica', 'Primary Idiopathic Thrombocytopaenia', 'PRIMARYPULMONARYHypertension', 'Prostate Disorder', 'Psoriatic Arthropathy', 'Psychoactive Substance Misuse', 'Recurrent pulmonary embolus', 'Renal Stones', 'Rheumatic Valve disease', 'Rheumatoid Arthritis', 'Secondary Polycythaemia', 'SECONDARYPULMONARYHypertension', 'Spinal stenosis', 'Spondylolisthesis', 'Stable Angina', 'Stroke CVA', 'Subdural Haematoma no-traumatic', 'Systemic Sclerosis', 'Thalassaemia', 'Thrombophilia', 'Thyroid Problem', 'Transient Ischaemic Attack', 'Tuberculosis', 'UnStable Angina', 'Urinary Incontinence', 'Urolithiasis', 'Uterovaginal Genital Prolapse', 'Valve disorder non-rheumatic multiple', 'Visual Impairment and Blindness', 'Vitiligo']
#   Comments_LW: ['Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'benign tumour - we could put all benign tumours into a single category if preferable?', 'Keep this - not currently covered by eFI list', 'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'Keep this - not currently covered by eFI list', "I don't mind if we don't include this", 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation', 'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'Keep this - not currently covered by eFI list', 'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'not covered by eFI, there is a visual impairment heading ', 'feature in both, can someone check both code lists to confirm they are the same?', "not in eFI, I'd like to keep it", 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'could combine into "heart block"', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'Keep this - not currently covered by eFI list', 'we can merge all the benign tumours into a single "benign tumour" category', 'I would separate PD tremor from benign tremor (included together in eFI)', 'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'covered by "toileting problems" in eFI', 'Keep this - not currently covered by eFI list', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'Keep this - not currently covered by eFI list', 'probably included under the "heart failure" code list but can someone check please?', 'probably included under the visual impairment code list but please check and if not, include', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'can join the benign tumours list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'in eFI, can someone check and compare the code lists?', 'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else', 'in eFI, can someone check and compare the code lists?', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'compare with eFI ischaemic heart disease list', 'Keep this - not currently covered by eFI list', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'compare to eFI  ', 'Keep t ...
# Keyword 'months' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'stress' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'system' found in:
#   Liverpool Diseases: ['Benign neoplasm Central nervous System', 'Disorders of Autonomic Nervous System', 'Systemic Sclerosis']
#   Comments_LW: []
# Keyword 'finances' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'mobility' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'parkinsonism' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'bathing' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'recognise' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'doesn' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'activity' found in:
#   Liverpool Diseases: ['Attention Deficit Hyperactivity Disorder']
#   Comments_LW: []
# Keyword 'fragility' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'diabetes' found in:
#   Liverpool Diseases: ['Diabetes']
#   Comments_LW: ['I would like these 3 to be separate but I can live with lumping them all together under a diabetes umbrella']
# Keyword 'falls' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'dyspnoea' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'bmi' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'depression' found in:
#   Liverpool Diseases: ['Depression']
#   Comments_LW: []
# Keyword 'anxiety' found in:
#   Liverpool Diseases: ['Anxiety']
#   Comments_LW: []
# Keyword 'alcohol' found in:
#   Liverpool Diseases: ['Alcohol Problem', 'Alcoholic Liver Disease', 'Alcohol-related Brain Injury']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else', "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding"]
# Keyword 'prognosis' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'stroke' found in:
#   Liverpool Diseases: ['Stroke CVA']
#   Comments_LW: ['probably contained within "stroke" code list in eFI but check', 'probably covered by "headache" but I would prefer to separate as it is independent stroke risk', 'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out']
# Keyword 'care' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'abdo' found in:
#   Liverpool Diseases: ['Abdominal Aortic Aneurysm', 'Abdominal Hernia']
#   Comments_LW: []
# Keyword 'shopping' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'brain' found in:
#   Liverpool Diseases: ['Alcohol-related Brain Injury']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'brain haemangiomas can be a problem if not addressed in childhood but as we are focusing on adulthood I could live with removing this']
# Keyword 'osteoarthritis' found in:
#   Liverpool Diseases: ['Osteoarthritis excluding spine']
#   Comments_LW: []
# Keyword 'prostate' found in:
#   Liverpool Diseases: ['Prostate Disorder']
#   Comments_LW: ['Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']
# Keyword 'something' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'organ' found in:
#   Liverpool Diseases: ['Cancer Solid organ']
#   Comments_LW: ['Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']
# Keyword 'codes' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'this can be removed if needs be, if renal impairment is a feature then this will be captured in CKD codes', 'Keep this - not currently covered by eFI list, might be some overlap with codes within "cognitive impairment" list - compare', 'merge codes lists', 'Keep this - not currently covered by eFI list although codes may be contained within the eFI "hypotension syncope" list so please check', 'Discuss. We could merge all the codes together to have an "ischaemic heart disease" code list like in eFI but I think there is value in having them separate', 'compare to eFI stroke list. These codes may be contained within their stroke code list but I would separate out']
# Keyword 'tremor' found in:
#   Liverpool Diseases: ['Benign tremor', 'Essential Tremor']
#   Comments_LW: ['I would separate PD tremor from benign tremor (included together in eFI)', 'can go under "tremor"', "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists"]
# Keyword 'sure' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list']
# Keyword 'conditions' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'can join the benign conditions list', 'can join benign conditions list', 'can join benign conditions list']
# Keyword 'illness' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']
# Keyword 'harm' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'fracture' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'smoker' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'dementia' found in:
#   Liverpool Diseases: ['Dementia']
#   Comments_LW: ['compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI']
# Keyword 'ex' found in:
#   Liverpool Diseases: ['Anorexia and Bulimia Nervosa', 'Choroid plexus Papillomanos', 'Osteoarthritis excluding spine', 'Peripheral Neuropathies Excluding Cranial nerve and carpal tunnel syndrome']
#   Comments_LW: ['Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']
# Keyword 'seizures' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'osteoporosis' found in:
#   Liverpool Diseases: ['Osteoporosis']
#   Comments_LW: []
# Keyword 'cancers' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['my preference is to separate out the cancers and not have a single cancer list like in eFI']
# Keyword 'i' found in:
# ...
#   Comments_LW: ['Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'benign tumour - we could put all benign tumours into a single category if preferable?', 'Keep this - not currently covered by eFI list', 'eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'Keep this - not currently covered by eFI list', "I don't mind if we don't include this", 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'Keep this - not currently covered by eFI list and is a risk factor for bleeding which could lead to hospitalisation', 'Keep this - not currently covered by eFI list - it is a chronic inflammatory condition so a risk factor for complex multimorbidity (higher rates of other autoimmune conditions)', 'Keep this - not currently covered by eFI list', 'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'not covered by eFI, there is a visual impairment heading ', 'feature in both, can someone check both code lists to confirm they are the same?', "not in eFI, I'd like to keep it", 'need to compare code lists for consistency. ', 'need to compare code lists for consistency. ', 'could combine into "heart block"', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'Keep this - not currently covered by eFI list', 'I would separate PD tremor from benign tremor (included together in eFI)', 'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'covered by "toileting problems" in eFI', 'Keep this - not currently covered by eFI list', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'Keep this - not currently covered by eFI list', 'probably included under the "heart failure" code list but can someone check please?', 'probably included under the visual impairment code list but please check and if not, include', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'in eFI, can someone check and compare the code lists?', 'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else', 'in eFI, can someone check and compare the code lists?', 'eFI has back pain specifically which we should have. I would also like "chronic pain" defined by medications (4 ort more issues in a 12 month period for 2 consecutive years) but I can live without if not possible ', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'Keep this - not currently covered by eFI list', 'compare with eFI ischaemic heart disease list', 'can be removed', 'Keep this - not currently covered by eFI list', 'compare to eFI cognitive impairment, dementia and memory probloems list. I am happy to split into those 3 categories as per eFI', 'Keep this - not currently covered by eFI list', 'can join the benign conditions list', 'I would like these 3 to be separat ...
# Keyword 'asthma' found in:
#   Liverpool Diseases: ['Asthma']
#   Comments_LW: []
# Keyword 'pref' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['benign tumour - we could put all benign tumours into a single category if preferable?', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'I would prefer to have this seperated from general CKD if possible', 'probably covered by "headache" but I would prefer to separate as it is independent stroke risk', 'may be covered by "general mental health" eFI list but I\'d prefer to separate', "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding", "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists"]
# Keyword 'incontinence' found in:
#   Liverpool Diseases: ['Urinary Incontinence']
#   Comments_LW: []
# Keyword 'cancer' found in:
#   Liverpool Diseases: ['Cancer Haematological', 'Cancer Solid organ']
#   Comments_LW: ['my preference is to separate out the cancers and not have a single cancer list like in eFI', 'Keep this - not currently covered by eFI list,. This is not cancer prostate problems. Prostate cancer is covered in the solid organ cancer lists']
# Keyword 'vascular' found in:
#   Liverpool Diseases: ['Peripheral Vascular Disease']
#   Comments_LW: []
# Keyword 'chronicity' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'mass' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'neuron' found in:
#   Liverpool Diseases: ['Motor neurone Disease (MND)']
#   Comments_LW: []
# Keyword 'transient' found in:
#   Liverpool Diseases: ['Transient Ischaemic Attack']
#   Comments_LW: []
# Keyword 'prefer' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['benign tumour - we could put all benign tumours into a single category if preferable?', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'covered in the "general mental health" category of eFI, this seems very broad to me and I\'d prefer to separate out', 'bipolar and schizophrenia are together under serious mental illness umbrella in eFI. I would prefer separate', 'my preference is to separate out the cancers and not have a single cancer list like in eFI', 'I would prefer to have this seperated from general CKD if possible', 'probably covered by "headache" but I would prefer to separate as it is independent stroke risk', 'may be covered by "general mental health" eFI list but I\'d prefer to separate', "currently in the alcohol problems heading for eFI but I'd prefer to separate it out as it is a risk factor for major bleeding", "eFI list is PD and tremors, I'd prefer to separate to 2 separate lists"]
# Keyword 'mean' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'outcomes' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']
# Keyword 'deficit' found in:
#   Liverpool Diseases: ['Attention Deficit Hyperactivity Disorder']
#   Comments_LW: []
# Keyword 'disorders' found in:
#   Liverpool Diseases: ['Disc Disorders', 'Disorders of Autonomic Nervous System', 'Non-rheumatic Aortic Valve Disorders', 'Non-rheumatic Mitral Valve Disorders']
#   Comments_LW: ['we can call this "seizure disorders" like eFI but need to merge the code lists so we are ctaching everything', 'can be merged into single "valve disorders" list', 'combine code lists for valve disorders']
# Keyword 'concerns' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'comapre' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'weakness' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'distinct' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'liver' found in:
#   Liverpool Diseases: ['Alcoholic Liver Disease', 'Autoimmune liver Disease', 'Chronic Liver disease And Viral hepatitis', 'Fatty Liver']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes', 'I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one', 'captured in "liver problems" of eFI. I would want to separate alcoholic liver disease, viral liver disease (Hep b and C) and other forms of liver disease', 'I would separate out liver - alcohol, liver - viral, liver - fatty and liver - everything else']
# Keyword 'headache' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['probably covered by "headache" but I would prefer to separate as it is independent stroke risk']
# Keyword 'loss' found in:
#   Liverpool Diseases: ['Hearing loss']
#   Comments_LW: ['not sure if this is covered by visual loss list. We may be better with a broad "occular problems" list']
# Keyword 'injury' found in:
#   Liverpool Diseases: ['Alcohol-related Brain Injury']
#   Comments_LW: ['eFI list includes codes for alcoholic liver disease. I would seperate and have 1) alcohol problems and 2) alcoholic liver disease and 3) alcohol brain injury. The current eFI list is missing some of the alcohol brain injury codes']
# Keyword 'liverpool' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']
# Keyword 'fatigue' found in:
#   Liverpool Diseases: ['Chronic Fatigue Syndrome']
#   Comments_LW: []
# Keyword 'mono' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'respiratory' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'motor' found in:
#   Liverpool Diseases: ['Motor neurone Disease (MND)']
#   Comments_LW: []
# Keyword 'sleep' found in:
#   Liverpool Diseases: ['Obstructive Sleep Apnoea']
#   Comments_LW: []
# Keyword 'vulnerability' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'bowel' found in:
#   Liverpool Diseases: ['Inflammatory Bowel Disease Crohn Disease', 'Inflammatory Bowel Disease Ulcerative Colitis', 'Irritable Bowel Syndrome']
#   Comments_LW: []
# Keyword 'environment' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'anaemia' found in:
#   Liverpool Diseases: ['Anaemia Aplastic', 'Anaemia Folate Deficiency', 'Anaemia Haemolytic', 'Anaemia Nos', 'Sickle cell anaemia']
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']
# Keyword 'dizziness' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'uc' found in:
#   Liverpool Diseases: ['Chronic Obstructive Pulmonary Disease (COPD)', 'Glaucoma', 'Obstructive Sleep Apnoea']
#   Comments_LW: ['Keep this - not currently covered by eFI list and should probably be on its own and not lumped with the other benign tumours owing to its affect on neighbouring structures and can cause serious illness', 'Keep. We need to expand the "severe mental illness" code list into separate lists for schizophrenia and bipolar. Outcomes for people with schizophrenia and enduring psychosis are much worse than for bipolar so they should not be lumped together or we\'ll lose that granularity']
# Keyword 'detail' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'crohns' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'deficiency' found in:
#   Liverpool Diseases: ['Anaemia Folate Deficiency']
#   Comments_LW: []
# Keyword 'headings' found in:
#   Liverpool Diseases: []
#   Comments_LW: ['I would prefer to separate these out and have separate headings for anaemia - iron, anaemia-folate, anaemia-B1, thalassaemia, sickle cell, aplastic anaemia, anaemia NOS (will include anaemia of chronic disease secondary to CKD, heart failure etc). We seem to have lost the code list for iron def anaemia from the Liverpool list - we will need one']
# Keyword 'haematinic' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
# Keyword 'hearing' found in:
#   Liverpool Diseases: ['Hearing loss']
#   Comments_LW: ['merge with "hearing impairment" from eFI']
# Keyword 'skin' found in:
#   Liverpool Diseases: []
#   Comments_LW: []
