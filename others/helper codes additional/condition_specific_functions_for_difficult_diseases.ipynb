# %%
#!/usr/bin/env python
# -*-coding:utf-8 -*-
'''
@File    :   condition_specific_functions_for_difficult_diseases.ipynb
@Time    :   2023/08/21 11:55:10
@Author  :   Asra Aslam 
@Version :   1.0
@Contact :   a.aslam2@leeds.ac.uk
@License :   (C)Copyright Asra Aslam DynAIRX
@Desc    :   This file is specifically designed for alcohol conditon, where we need to extract 
             snomed codes from other splitted categories and compare with categories in efi file
             and report the remaining ones
'''

import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
filepaths_source_database_splitted_condition=['output/pulmonary_related_diseases/grouped_database_with_snomed_COPD.csv'] #['output/alcohol_manual_analysis/Alcohol Harmful.csv', 'output/alcohol_manual_analysis/Alcohol High Risk.csv', 'output/alcohol_manual_analysis/Alcohol Low Risk.csv', 'output/alcohol_manual_analysis/Alcohol Previous High Risk.csv', 'output/alcohol_manual_analysis/Alcohol Zero.csv'] #['output/alcohol_manual_analysis/1 Alcoholic Liver Disease.csv', 'output/alcohol_manual_analysis/2 Liver Disease - Viral.csv', 'output/alcohol_manual_analysis/3 Oesophageal varices.csv', 'output/alcohol_manual_analysis/4 Fatty Liver.csv', 'output/alcohol_manual_analysis/5 Alcohol-related Brain Injury.csv', 'output/alcohol_manual_analysis/6 Liver Disease - Other.csv', 'output/alcohol_manual_analysis/7 Autoimmune liver Disease_doubt.csv'] #---Lauren file for grouping----
filepath_target_database_efi_general_condition="output/pulmonary_related_diseases/grouped_database_with_snomed_Chronic Obstructive Pulmonary Disease (COPD).csv" #"output/alcohol_manual_analysis/grouped_database_with_snomed_Alcohol Problem.csv" #"output/alcohol_manual_analysis/efi Liver problems.csv" #---efi file for grouping----
filepath_output_database_remaining_SNOMED="output/pulmonary_related_diseases/Remaining_copd_problems_with_snomed.csv"

# %%
df_database_target = pd.read_csv(filepath_target_database_efi_general_condition, dtype={'SNOMEDCT_CONCEPTID': str}) 
df_database_target
# Out:
#     SnomedCTConceptId                                               Term  \
# 0           135836000      End stage chronic obstructive airways disease
# 1            13645005                Chronic obstructive airways disease
# 2            13645005            Chronic obstructive airways disease NOS
# 3            13645005              Chronic obstructive pulmonary disease
# 4            13645005          Chronic obstructive pulmonary disease NOS
# 5            13645005  Other specified chronic obstructive airways di...
# 6            13645005  Other specified chronic obstructive pulmonary ...
# 7            13645005  [X]Other specified chronic obstructive pulmona...
# 8            16003001                            Giant bullous emphysema
# 9           185086009                           Emphysematous bronchitis
# 10          185086009                     Obstructive chronic bronchitis
# 11          185086009                 Obstructive chronic bronchitis NOS
# 12          195949008                          Chronic wheezy bronchitis
# 13          195951007  Acute exacerbation of chronic obstructive airw...
# 14          195953005   Mixed simple and mucopurulent chronic bronchitis
# 15          195957006                          Chronic bullous emphysema
# 16          195957006                      Chronic bullous emphysema NOS
# 17          195958001                        Segmental bullous emphysema
# 18          195959009                            Zonal bullous emphysema
# 19          195963002                          Acute vesicular emphysema
# 20          196026004            Chronic emphysema due to chemical fumes
# 21          196027008   Obliterative bronchiolitis due to chemical fumes
# 22          266355005                    Bullous emphysema with collapse
# 23          266356006                        Atrophic (senile) emphysema
# 24    293991000000106  Very severe chronic obstructive pulmonary disease
# 25          313296004         Mild chronic obstructive pulmonary disease
# 26          313297008     Moderate chronic obstructive pulmonary disease
# 27          313299006       Severe chronic obstructive pulmonary disease
# 28    383611000000102  At risk of chronic obstructive pulmonary disea...
# 29           40100001                           Bronchiolitis obliterans
# 30           45145000                     MacLeod's unilateral emphysema
# 31           46802002                                     Smokers' cough
# 32            4981000                               Panlobular emphysema
# 33           52571006                          Chronic tracheobronchitis
# 34           61937009                          Simple chronic bronchitis
# 35           61937009                      Simple chronic bronchitis NOS
# 36           63480004                                 Chronic bronchitis
# 37           63480004                             Chronic bronchitis NOS
# 38           63480004                           Other chronic bronchitis
# 39           63480004                       Other chronic bronchitis NOS
# 40           68328006                            Centrilobular emphysema
# 41           74417001                    Mucopurulent chronic bronchitis
# 42           74417001                Mucopurulent chronic bronchitis NOS
# 43            7457009                                 Chronic tracheitis
# 44           77690003                       Acute interstitial emphysema
# 45           84409004                           Fetid chronic bronchitis
# 46           84409004                        Purulent chronic bronchitis
# 47    866901000000103                            Eosinophilic bronchitis
# 48           87433001                                      Emphysema NOS
# 49           87433001                                    Other emphysema
# 50           87433001                                Other emphysema NOS
# 51           87433001                                 [X]Other emphysema
# 52           89549007                       Chronic catarrhal bronchitis
#
#                                          Disease  Otherinstructions  \
# 0   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 1   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 2   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 3   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 4   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 5   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 6   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 7   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 8   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 9   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 10  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 11  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 12  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 13  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 14  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 15  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 16  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 17  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 18  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 19  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 20  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 21  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 22  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 23  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 24  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 25  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 26  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 27  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 28  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 29  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 30  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 31  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 32  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 33  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 34  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 35  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 36  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 37  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 38  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 39  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 40  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 41  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 42  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 43  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 44  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 45  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 46  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 47  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 48  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 49  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 50  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 51  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 52  Chronic Obstructive Pulmonary Disease (COPD)                NaN
#
#                  origin
# 0   ['Lauren_codelist']
# 1   ['Lauren_codelist']
# 2   ['Lauren_codelist']
# 3   ['Lauren_codelist']
# 4   ['Lauren_codelist']
# 5   ['Lauren_codelist']
# 6   ['Lauren_codelist']
# 7   ['Lauren_codelist']
# 8   ['Lauren_codelist']
# 9   ['Lauren_codelist']
# 10  ['Lauren_codelist']
# 11  ['Lauren_codelist']
# 12  ['Lauren_codelist']
# 13  ['Lauren_codelist']
# 14  ['Lauren_codelist']
# 15  ['Lauren_codelist']
# 16  ['Lauren_codelist']
# 17  ['Lauren_codelist']
# 18  ['Lauren_codelist']
# 19  ['Lauren_codelist']
# 20  ['Lauren_codelist']
# 21  ['Lauren_codelist']
# 22  ['Lauren_codelist']
# 23  ['Lauren_codelist']
# 24  ['Lauren_codelist']
# 25  ['Lauren_codelist']
# 26  ['Lauren_codelist']
# 27  ['Lauren_codelist']
# 28  ['Lauren_codelist']
# 29  ['Lauren_codelist']
# 30  ['Lauren_codelist']
# 31  ['Lauren_codelist']
# 32  ['Lauren_codelist']
# 33  ['Lauren_codelist']
# 34  ['Lauren_codelist']
# 35  ['Lauren_codelist']
# 36  ['Lauren_codelist']
# 37  ['Lauren_codelist']
# 38  ['Lauren_codelist']
# 39  ['Lauren_codelist']
# 40  ['Lauren_codelist']
# 41  ['Lauren_codelist']
# 42  ['Lauren_codelist']
# 43  ['Lauren_codelist']
# 44  ['Lauren_codelist']
# 45  ['Lauren_codelist']
# 46  ['Lauren_codelist']
# 47  ['Lauren_codelist']
# 48  ['Lauren_codelist']
# 49  ['Lauren_codelist']
# 50  ['Lauren_codelist']
# 51  ['Lauren_codelist']
# 52  ['Lauren_codelist']

# %%
# rename SNOMEDCT_CONCEPTID, Deficit and Codedescription column in efi list same as LW list
df_database_target.rename(columns={'SNOMEDCT_CONCEPTID':'SnomedCTConceptId'}, inplace=True)
df_database_target.rename(columns={'Codedescription':'Term'}, inplace=True)
df_database_target.rename(columns={'Deficit':'Disease'}, inplace=True)
df_database_target.columns
# Out:
# Index(['SnomedCTConceptId', 'Term', 'Disease', 'Otherinstructions', 'origin'], dtype='object')

# %%
df_database_target.dtypes
# Out:
# SnomedCTConceptId      int64
# Term                  object
# Disease               object
# Otherinstructions    float64
# origin                object
# dtype: object

# %%
#merging all input files to get used snomed codes column in one---
df_concatenated = pd.DataFrame(columns=['SnomedCTConceptId', 'Term', 'Disease', 'Otherinstructions', 'origin', 'Comment']) #--just an empty dataframe at first--
for filepath in filepaths_source_database_splitted_condition:
    df_database_source = pd.read_csv(filepath, dtype={'SnomedCTConceptId': str}) 
    print("For file: ", filepath)
    #print(df_database_source)
    print(df_database_source.columns)
    df_concatenated = pd.concat([df_concatenated, df_database_source], ignore_index=True, sort=False)
    print(df_concatenated)
# Out:
# For file:  output/pulmonary_related_diseases/grouped_database_with_snomed_COPD.csv
# Index(['SnomedCTConceptId', 'Term', 'Disease', 'Otherinstructions', 'origin'], dtype='object')
#      SnomedCTConceptId                                               Term  \
# 0    10692761000119100  asthma-chronic obstructive pulmonary disease o...
# 1      110011000000107  Did not attend chronic obstructive pulmonary d...
# 2            135836000                     End stag chron obst airway dis
# 3             13645005                   Chronic obstructive lung disease
# 4             15081005                           Pulmonary rehabilitation
# ..                 ...                                                ...
# 103    866901000000103                            Eosinophilic bronchitis
# 104           87433001                                          Emphysema
# 105    892321000000109  chronic obstruct pulmonary disease management ...
# 106           89549007                          Simple chronic bronchitis
# 107    941201000000103     chronic obstructive pulmonary disease resolved
#
#     Disease Otherinstructions   origin Comment
# 0      COPD               NaN  ['efi']     NaN
# 1      COPD               NaN  ['efi']     NaN
# 2      COPD               NaN  ['efi']     NaN
# 3      COPD               NaN  ['efi']     NaN
# 4      COPD               NaN  ['efi']     NaN
# ..      ...               ...      ...     ...
# 103    COPD               NaN  ['efi']     NaN
# 104    COPD               NaN  ['efi']     NaN
# 105    COPD               NaN  ['efi']     NaN
# 106    COPD               NaN  ['efi']     NaN
# 107    COPD               NaN  ['efi']     NaN
#
# [108 rows x 6 columns]

# %%
df_concatenated
# Out:
#      SnomedCTConceptId                                               Term  \
# 0    10692761000119100  asthma-chronic obstructive pulmonary disease o...
# 1      110011000000107  Did not attend chronic obstructive pulmonary d...
# 2            135836000                     End stag chron obst airway dis
# 3             13645005                   Chronic obstructive lung disease
# 4             15081005                           Pulmonary rehabilitation
# ..                 ...                                                ...
# 103    866901000000103                            Eosinophilic bronchitis
# 104           87433001                                          Emphysema
# 105    892321000000109  chronic obstruct pulmonary disease management ...
# 106           89549007                          Simple chronic bronchitis
# 107    941201000000103     chronic obstructive pulmonary disease resolved
#
#     Disease Otherinstructions   origin Comment
# 0      COPD               NaN  ['efi']     NaN
# 1      COPD               NaN  ['efi']     NaN
# 2      COPD               NaN  ['efi']     NaN
# 3      COPD               NaN  ['efi']     NaN
# 4      COPD               NaN  ['efi']     NaN
# ..      ...               ...      ...     ...
# 103    COPD               NaN  ['efi']     NaN
# 104    COPD               NaN  ['efi']     NaN
# 105    COPD               NaN  ['efi']     NaN
# 106    COPD               NaN  ['efi']     NaN
# 107    COPD               NaN  ['efi']     NaN
#
# [108 rows x 6 columns]

# %%
#df_concatenated.to_csv('output/alcohol_manual_analysis/concatenated_alcohol_categories.csv')

# %%
df_concatenated.SnomedCTConceptId
# Out:
# 0      10692761000119100
# 1        110011000000107
# 2              135836000
# 3               13645005
# 4               15081005
#              ...
# 103      866901000000103
# 104             87433001
# 105      892321000000109
# 106             89549007
# 107      941201000000103
# Name: SnomedCTConceptId, Length: 108, dtype: object

# %%
df_database_target.SnomedCTConceptId.isin(df_concatenated.SnomedCTConceptId)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# Name: SnomedCTConceptId, dtype: bool

# %%
df_remaining_rows=df_database_target[~df_database_target.SnomedCTConceptId.isin(df_concatenated.SnomedCTConceptId)]
df_remaining_rows
# Out:
#     SnomedCTConceptId                                               Term  \
# 0           135836000      End stage chronic obstructive airways disease
# 1            13645005                Chronic obstructive airways disease
# 2            13645005            Chronic obstructive airways disease NOS
# 3            13645005              Chronic obstructive pulmonary disease
# 4            13645005          Chronic obstructive pulmonary disease NOS
# 5            13645005  Other specified chronic obstructive airways di...
# 6            13645005  Other specified chronic obstructive pulmonary ...
# 7            13645005  [X]Other specified chronic obstructive pulmona...
# 8            16003001                            Giant bullous emphysema
# 9           185086009                           Emphysematous bronchitis
# 10          185086009                     Obstructive chronic bronchitis
# 11          185086009                 Obstructive chronic bronchitis NOS
# 12          195949008                          Chronic wheezy bronchitis
# 13          195951007  Acute exacerbation of chronic obstructive airw...
# 14          195953005   Mixed simple and mucopurulent chronic bronchitis
# 15          195957006                          Chronic bullous emphysema
# 16          195957006                      Chronic bullous emphysema NOS
# 17          195958001                        Segmental bullous emphysema
# 18          195959009                            Zonal bullous emphysema
# 19          195963002                          Acute vesicular emphysema
# 20          196026004            Chronic emphysema due to chemical fumes
# 21          196027008   Obliterative bronchiolitis due to chemical fumes
# 22          266355005                    Bullous emphysema with collapse
# 23          266356006                        Atrophic (senile) emphysema
# 24    293991000000106  Very severe chronic obstructive pulmonary disease
# 25          313296004         Mild chronic obstructive pulmonary disease
# 26          313297008     Moderate chronic obstructive pulmonary disease
# 27          313299006       Severe chronic obstructive pulmonary disease
# 28    383611000000102  At risk of chronic obstructive pulmonary disea...
# 29           40100001                           Bronchiolitis obliterans
# 30           45145000                     MacLeod's unilateral emphysema
# 31           46802002                                     Smokers' cough
# 32            4981000                               Panlobular emphysema
# 33           52571006                          Chronic tracheobronchitis
# 34           61937009                          Simple chronic bronchitis
# 35           61937009                      Simple chronic bronchitis NOS
# 36           63480004                                 Chronic bronchitis
# 37           63480004                             Chronic bronchitis NOS
# 38           63480004                           Other chronic bronchitis
# 39           63480004                       Other chronic bronchitis NOS
# 40           68328006                            Centrilobular emphysema
# 41           74417001                    Mucopurulent chronic bronchitis
# 42           74417001                Mucopurulent chronic bronchitis NOS
# 43            7457009                                 Chronic tracheitis
# 44           77690003                       Acute interstitial emphysema
# 45           84409004                           Fetid chronic bronchitis
# 46           84409004                        Purulent chronic bronchitis
# 47    866901000000103                            Eosinophilic bronchitis
# 48           87433001                                      Emphysema NOS
# 49           87433001                                    Other emphysema
# 50           87433001                                Other emphysema NOS
# 51           87433001                                 [X]Other emphysema
# 52           89549007                       Chronic catarrhal bronchitis
#
#                                          Disease  Otherinstructions  \
# 0   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 1   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 2   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 3   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 4   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 5   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 6   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 7   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 8   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 9   Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 10  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 11  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 12  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 13  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 14  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 15  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 16  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 17  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 18  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 19  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 20  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 21  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 22  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 23  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 24  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 25  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 26  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 27  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 28  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 29  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 30  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 31  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 32  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 33  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 34  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 35  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 36  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 37  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 38  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 39  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 40  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 41  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 42  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 43  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 44  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 45  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 46  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 47  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 48  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 49  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 50  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 51  Chronic Obstructive Pulmonary Disease (COPD)                NaN
# 52  Chronic Obstructive Pulmonary Disease (COPD)                NaN
#
#                  origin
# 0   ['Lauren_codelist']
# 1   ['Lauren_codelist']
# 2   ['Lauren_codelist']
# 3   ['Lauren_codelist']
# 4   ['Lauren_codelist']
# 5   ['Lauren_codelist']
# 6   ['Lauren_codelist']
# 7   ['Lauren_codelist']
# 8   ['Lauren_codelist']
# 9   ['Lauren_codelist']
# 10  ['Lauren_codelist']
# 11  ['Lauren_codelist']
# 12  ['Lauren_codelist']
# 13  ['Lauren_codelist']
# 14  ['Lauren_codelist']
# 15  ['Lauren_codelist']
# 16  ['Lauren_codelist']
# 17  ['Lauren_codelist']
# 18  ['Lauren_codelist']
# 19  ['Lauren_codelist']
# 20  ['Lauren_codelist']
# 21  ['Lauren_codelist']
# 22  ['Lauren_codelist']
# 23  ['Lauren_codelist']
# 24  ['Lauren_codelist']
# 25  ['Lauren_codelist']
# 26  ['Lauren_codelist']
# 27  ['Lauren_codelist']
# 28  ['Lauren_codelist']
# 29  ['Lauren_codelist']
# 30  ['Lauren_codelist']
# 31  ['Lauren_codelist']
# 32  ['Lauren_codelist']
# 33  ['Lauren_codelist']
# 34  ['Lauren_codelist']
# 35  ['Lauren_codelist']
# 36  ['Lauren_codelist']
# 37  ['Lauren_codelist']
# 38  ['Lauren_codelist']
# 39  ['Lauren_codelist']
# 40  ['Lauren_codelist']
# 41  ['Lauren_codelist']
# 42  ['Lauren_codelist']
# 43  ['Lauren_codelist']
# 44  ['Lauren_codelist']
# 45  ['Lauren_codelist']
# 46  ['Lauren_codelist']
# 47  ['Lauren_codelist']
# 48  ['Lauren_codelist']
# 49  ['Lauren_codelist']
# 50  ['Lauren_codelist']
# 51  ['Lauren_codelist']
# 52  ['Lauren_codelist']

# %%
df_remaining_rows.to_csv(filepath_output_database_remaining_SNOMED, index=False)
